# %% [markdown]
# # 04 Frozen DistilBERT GA Model
#
# Combine cached frozen DistilBERT embeddings with engineered feature scores and run the GA-weighted modeling workflow.

# %%
from pathlib import Path

# If using Google Drive later:
# BASE_DIR = Path("/content/drive/MyDrive/Thesis_Modeling/thesis-modeling")

# If uploaded directly to Colab:
# BASE_DIR = Path("/content/thesis-modeling")

# Local fallback:
BASE_DIR = Path("..")

DATA_DIR = BASE_DIR / "data" / "06_model_ready"
